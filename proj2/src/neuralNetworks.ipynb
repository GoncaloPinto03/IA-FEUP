# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
import time
import seaborn as sns

# %%
file_path = 'Titanic Dataset.csv'
titanic_data = pd.read_csv(file_path,delimiter=",")
titanic_data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
titanic_data = pd.read_csv('Titanic Dataset.csv')
titanic_data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic_data.describe (include='all').T
# Out:
#             count unique                   top freq        mean        std  \
# pclass     1309.0    NaN                   NaN  NaN    2.294882   0.837836
# survived   1309.0    NaN                   NaN  NaN    0.381971   0.486055
# name         1309   1307  Connolly, Miss. Kate    2         NaN        NaN
# sex          1309      2                  male  843         NaN        NaN
# age        1046.0    NaN                   NaN  NaN   29.881138  14.413493
# sibsp      1309.0    NaN                   NaN  NaN    0.498854   1.041658
# parch      1309.0    NaN                   NaN  NaN    0.385027    0.86556
# ticket       1309    929              CA. 2343   11         NaN        NaN
# fare       1308.0    NaN                   NaN  NaN   33.295479  51.758668
# cabin         295    186           C23 C25 C27    6         NaN        NaN
# embarked     1307      3                     S  914         NaN        NaN
# ...

# %%
file_path = 'Titanic Dataset.csv'
titanic_data = pd.read_csv(file_path,delimiter=",")
input_names = list(titanic_data.columns)
all_inputs = titanic_data[input_names].values
all_classes = titanic_data['survived'].values

# %%
from sklearn.model_selection import train_test_split

(training_inputs, testing_inputs, training_classes, testing_classes) = train_test_split(all_inputs, all_classes, test_size=0.25, random_state=1)
